# %% [markdown]
# # Pandas With WINDOWS STORE DATASET
#
# ** LINK For DATA SET :  https://github.com/sunilkumar9740/CSV_DATASET **

# %%
import pandas as pd
df=pd.read_csv('msft.csv') #read the csv file
df.head() #display the table
# Out:
#                                                 Name  Rating  \
# 0                                     Dynamic Reader     3.5
# 1  Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                         BookViewer     3.5
# 3                                 Brick Instructions     3.5
# 4  Introduction to Python Programming by GoLearni...     2.0
#
#    No of people Rated Category        Date Price
# 0                 268    Books  07-01-2014  Free
# 1                 627    Books  08-01-2014  Free
# 2                 593    Books  29-02-2016  Free
# 3                 684    Books  30-01-2018  Free
# 4                 634    Books  30-01-2018  Free

# %%
df.head(10) #display the first 10 rows
# Out:
#                                                 Name  Rating  \
# 0                                     Dynamic Reader     3.5
# 1  Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                         BookViewer     3.5
# 3                                 Brick Instructions     3.5
# 4  Introduction to Python Programming by GoLearni...     2.0
# 5                                     Gurbani Reader     4.5
# 6                                         NFO Viewer     4.5
# 7                                 Text to Speech TTS     3.0
# 8                                         ACK Comics     4.0
# 9  Learn Biology and Human Body Anatomy by GoLear...     3.5
#
#    No of people Rated Category        Date Price
# 0                 268    Books  07-01-2014  Free
# 1                 627    Books  08-01-2014  Free
# 2                 593    Books  29-02-2016  Free
# 3                 684    Books  30-01-2018  Free
# ...

# %%
print(df.columns) # diplay the columns details  in the table
# Out:
# Index(['Name', 'Rating', 'No of people Rated', 'Category', 'Date', 'Price'], dtype='object')

# %%
print(df.columns[2]) #display the particular columns in the table using index method
# Out:
# No of people Rated

# %%
print(df.iloc[2]) #display the particular row details in the table (particular person detials )
# Out:
# Name                  BookViewer
# Rating                       3.5
# No of people Rated           593
# Category                   Books
# Date                  29-02-2016
# Price                       Free
# Name: 2, dtype: object

# %%
print(df.iloc[2,4]) #Display the particular rows with particular columns details 'Specific locotion'
# Out:
# 29-02-2016

# %%
print(df.iloc[5:7]) # display the 5th to 7th rows details
# Out:
#              Name  Rating  No of people Rated Category        Date Price
# 5  Gurbani Reader     4.5                 399    Books  18-01-2017  Free
# 6      NFO Viewer     4.5                 566    Books  13-11-2012  Free

# %%
print(df['Name']) #Display the 'name'columns of the all rows details 'Single column'
# Out:
# 0                                          Dynamic Reader
# 1       Chemistry, Organic Chemistry and Biochemistry-...
# 2                                              BookViewer
# 3                                      Brick Instructions
# 4       Introduction to Python Programming by GoLearni...
#                               ...
# 5317                                              JS King
# 5318                                          MQTTSniffer
# 5319                        Dev Utils - JSON, CSV and XML
# 5320                                          Simply Text
# 5321                                                  NaN
# Name: Name, Length: 5322, dtype: object

# %%
print(df[['Name','Rating']]) #display the name and ratings columsns rows details 'Multiple columns'
# Out:
#                                                    Name  Rating
# 0                                        Dynamic Reader     3.5
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# ...                                                 ...     ...
# 5317                                            JS King     1.0
# 5318                                        MQTTSniffer     2.5
# 5319                      Dev Utils - JSON, CSV and XML     4.0
# 5320                                        Simply Text     4.0
# 5321                                                NaN     NaN
#
# [5322 rows x 2 columns]

# %%
df.describe() #It will show the means and counts etc details
# Out:
#             Rating  No of people Rated
# count  5321.000000         5322.000000
# mean      3.792708          551.873168
# std       0.991681          259.820088
# min       1.000000          100.000000
# 25%       3.500000          327.000000
# 50%       4.000000          548.000000
# 75%       4.500000          779.000000
# max       5.000000         1000.000000

# %%
df.sort_values('Name') # sort by name
# Out:
#                                   Name  Rating  No of people Rated  \
# 5020                        #1 Weather     3.5                 681
# 2037                       #BABYLON'13     3.5                 966
# 1299                             #Code     4.0                 855
# 1604                              #UWP     4.0                 537
# 3079                            #Yatzy     4.0                 302
# ...                                ...     ...                 ...
# 426                           道学经典(有声)     5.0                 813
# 4952                         降水にゃうきゃすと     4.5                 543
# 409                           鲁迅全集(有声)     5.0                 594
# 3747  라디오와 멀티미디어(Radio and Multimedia)     3.5                 919
# 5321                               NaN     NaN                 948
#
#                Category        Date Price
# 5020   News and Weather  03-06-2016  Free
# 2037             Social  02-03-2015  Free
# ...

# %%
df.sort_values(['Name','Rating']) #Sort by multiple columns
# Out:
#                                   Name  Rating  No of people Rated  \
# 5020                        #1 Weather     3.5                 681
# 2037                       #BABYLON'13     3.5                 966
# 1299                             #Code     4.0                 855
# 1604                              #UWP     4.0                 537
# 3079                            #Yatzy     4.0                 302
# ...                                ...     ...                 ...
# 426                           道学经典(有声)     5.0                 813
# 4952                         降水にゃうきゃすと     4.5                 543
# 409                           鲁迅全集(有声)     5.0                 594
# 3747  라디오와 멀티미디어(Radio and Multimedia)     3.5                 919
# 5321                               NaN     NaN                 948
#
#                Category        Date Price
# 5020   News and Weather  03-06-2016  Free
# 2037             Social  02-03-2015  Free
# ...

# %%
df.sort_values(['Name','Rating'],ascending= False) #diplay the Name and Rating with sorting Muliple columns
# Out:
#                                   Name  Rating  No of people Rated  \
# 3747  라디오와 멀티미디어(Radio and Multimedia)     3.5                 919
# 409                           鲁迅全集(有声)     5.0                 594
# 4952                         降水にゃうきゃすと     4.5                 543
# 426                           道学经典(有声)     5.0                 813
# 383                               追书悦读     3.5                 864
# ...                                ...     ...                 ...
# 1604                              #UWP     4.0                 537
# 1299                             #Code     4.0                 855
# 2037                       #BABYLON'13     3.5                 966
# 5020                        #1 Weather     3.5                 681
# 5321                               NaN     NaN                 948
#
#                Category        Date Price
# 3747  Multimedia Design  12-03-2018  Free
# 409               Books  11-03-2020  Free
# ...

# %%
df.sort_values('Rating',ascending= False) #Sort the rows by its  highest rating order
# Out:
#                                          Name  Rating  No of people Rated  \
# 2660                       Inner Kung Fu Game     5.0                 520
# 1472   Windows Package Manager YAML Generator     5.0                 970
# 3766                            Color Factory     5.0                 110
# 3767                                 Pick App     5.0                 540
# 1417                     Brainf*ck# (Preview)     5.0                 807
# ...                                       ...     ...                 ...
# 5177                        eBooks for Kindle     1.0                 450
# 5178  eBook Reader (ePub, Mobi and PDF books)     1.0                 824
# 2943                             Kids & Games     1.0                 694
# 3071                    Falar, Ler e Escrever     1.0                 747
# 5321                                      NaN     NaN                 948
#
#                 Category        Date     Price
# ...

# %%
df.head(5)
# Out:
#                                                 Name  Rating  \
# 0                                     Dynamic Reader     3.5
# 1  Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                         BookViewer     3.5
# 3                                 Brick Instructions     3.5
# 4  Introduction to Python Programming by GoLearni...     2.0
#
#    No of people Rated Category        Date Price
# 0                 268    Books  07-01-2014  Free
# 1                 627    Books  08-01-2014  Free
# 2                 593    Books  29-02-2016  Free
# 3                 684    Books  30-01-2018  Free
# 4                 634    Books  30-01-2018  Free

# %%
df[df['Rating']>3] # Diplay the rating who got more then 3
# Out:
#                                   Name  Rating  No of people Rated  \
# 0                       Dynamic Reader     3.5                 268
# 2                           BookViewer     3.5                 593
# 3                   Brick Instructions     3.5                 684
# 5                       Gurbani Reader     4.5                 399
# 6                           NFO Viewer     4.5                 566
# ...                                ...     ...                 ...
# 5312  Assets Resizer for Windows Store     3.5                 566
# 5313                         WWWmaster     3.5                 150
# 5314                        HexToolkit     3.5                 214
# 5319     Dev Utils - JSON, CSV and XML     4.0                 862
# 5320                       Simply Text     4.0                 386
#
#              Category        Date     Price
# 0               Books  07-01-2014      Free
# 2               Books  29-02-2016      Free
# ...

# %%
df.sort_values('No of people Rated') #sorting
# Out:
#                                                  Name  Rating  \
# 3188                                       Shot Notes     4.5
# 140                                        Deaf Bible     5.0
# 1264                                              TPi     5.0
# 1295                                Python 3.9 (Beta)     5.0
# 3190  Survey for money: earn money paid surveys guide     4.5
# ...                                               ...     ...
# 1883                                              ILN     5.0
# 560                               CDBS Facility Query     3.0
# 1929                        Psychic Reader Paranormal     3.5
# 3260                                   Daily Panchang     3.5
# 3940                      Guitar Lessons Beginners #1     3.5
#
#       No of people Rated         Category        Date Price
# 3188                 100        Lifestyle  04-09-2017  Free
# 140                  100            Books  04-08-2016  Free
# ...

# %%
df[df['No of people Rated'] >= 500] #Display the rows how got rated more then 500
# Out:
#                                                    Name  Rating  \
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# 6                                            NFO Viewer     4.5
# ...                                                 ...     ...
# 5316                                          Get Color     3.0
# 5317                                            JS King     1.0
# 5318                                        MQTTSniffer     2.5
# 5319                      Dev Utils - JSON, CSV and XML     4.0
# 5321                                                NaN     NaN
#
#       No of people Rated         Category        Date     Price
# 1                    627            Books  08-01-2014      Free
# 2                    593            Books  29-02-2016      Free
# ...

# %%
df[df['No of people Rated'] >= 500] |
# Out:
#                                                    Name  Rating  \
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# 6                                            NFO Viewer     4.5
# ...                                                 ...     ...
# 5315                         Visual Studio Image Scaler     1.0
# 5316                                          Get Color     3.0
# 5317                                            JS King     1.0
# 5319                      Dev Utils - JSON, CSV and XML     4.0
# 5321                                                NaN     NaN
#
#       No of people Rated         Category        Date     Price
# 1                    627            Books  08-01-2014      Free
# 2                    593            Books  29-02-2016      Free
# ...

# %%
df[df['Price']=='Free'] #sort the name who got free price
# Out:
#                                                    Name  Rating  \
# 0                                        Dynamic Reader     3.5
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# ...                                                 ...     ...
# 5158                                        Kad će Kiša     5.0
# 5159                                            Newseen     4.5
# 5160                                             Newser     3.5
# 5161                                 Recent Earthquakes     3.0
# 5162                                       Console news     5.0
#
#       No of people Rated          Category        Date Price
# 0                    268             Books  07-01-2014  Free
# 1                    627             Books  08-01-2014  Free
# ...

# %%
df[df['Category'] == 'Books']
# Out:
#                                                    Name  Rating  \
# 0                                        Dynamic Reader     3.5
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# ...                                                 ...     ...
# 5214                               The King James Bible     1.5
# 5215                                       EZ Genealogy     3.0
# 5216                  Concise Oxford Spanish Dictionary     2.5
# 5217  La Bible en Français par Louis Segond (French ...     1.5
# 5218                 Disney Infinity Collection Tracker     4.0
#
#       No of people Rated Category        Date     Price
# 0                    268    Books  07-01-2014      Free
# 1                    627    Books  08-01-2014      Free
# ...

# %%
df[df['Category'] == 'Books']
# Out:
#                                                    Name  Rating  \
# 0                                        Dynamic Reader     3.5
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# ...                                                 ...     ...
# 5214                               The King James Bible     1.5
# 5215                                       EZ Genealogy     3.0
# 5216                  Concise Oxford Spanish Dictionary     2.5
# 5217  La Bible en Français par Louis Segond (French ...     1.5
# 5218                 Disney Infinity Collection Tracker     4.0
#
#       No of people Rated Category        Date     Price
# 0                    268    Books  07-01-2014      Free
# 1                    627    Books  08-01-2014      Free
# ...

# %%
df.loc[df['Category'] == 'Books']
# Out:
#                                                    Name  Rating  \
# 0                                        Dynamic Reader     3.5
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# ...                                                 ...     ...
# 5214                               The King James Bible     1.5
# 5215                                       EZ Genealogy     3.0
# 5216                  Concise Oxford Spanish Dictionary     2.5
# 5217  La Bible en Français par Louis Segond (French ...     1.5
# 5218                 Disney Infinity Collection Tracker     4.0
#
#       No of people Rated Category        Date     Price
# 0                    268    Books  07-01-2014      Free
# 1                    627    Books  08-01-2014      Free
# ...

# %%
df[(df['Category'] == 'Developer Tools') & (df['No of people Rated'] >= 500)] #sort by category and greater then canditiondf
# Out:
#                                Name  Rating  No of people Rated  \
# 1278                     Python 3.8     3.5                 697
# 1279               Ubuntu 20.04 LTS     4.5                 720
# 1280               Windows Terminal     4.0                 820
# 1281                         Ubuntu     4.5                 718
# 1283                     Python 3.7     3.5                 804
# ...                             ...     ...                 ...
# 5315     Visual Studio Image Scaler     1.0                 756
# 5316                      Get Color     3.0                 785
# 5317                        JS King     1.0                 720
# 5318                    MQTTSniffer     2.5                 500
# 5319  Dev Utils - JSON, CSV and XML     4.0                 862
#
#              Category        Date     Price
# 1278  Developer Tools  18-12-2018      Free
# 1279  Developer Tools  17-04-2020      Free
# 1280  Developer Tools  21-06-2019      Free
# ...

# %%
df.loc[df['Category']=='Developer Tools','Category']='Developer'

# %%
df.colums[4]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-eebed5c675d3> in <module>
# ----> 1 df.colums[4]
#
# c:\users\sunil\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
df[df['Category']=='Developer']
# Out:
#                                Name  Rating  No of people Rated   Category  \
# 1278                     Python 3.8     3.5                 697  Developer
# 1279               Ubuntu 20.04 LTS     4.5                 720  Developer
# 1280               Windows Terminal     4.0                 820  Developer
# 1281                         Ubuntu     4.5                 718  Developer
# 1282                    Arduino IDE     4.0                 192  Developer
# ...                             ...     ...                 ...        ...
# 5316                      Get Color     3.0                 785  Developer
# 5317                        JS King     1.0                 720  Developer
# 5318                    MQTTSniffer     2.5                 500  Developer
# 5319  Dev Utils - JSON, CSV and XML     4.0                 862  Developer
# 5320                    Simply Text     4.0                 386  Developer
#
#             Date     Price
# 1278  18-12-2018      Free
# ...
